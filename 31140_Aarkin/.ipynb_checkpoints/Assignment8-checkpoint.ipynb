# %%
import numpy as np
import seaborn as sns

sns.set(style="white")

import pandas as pd

df = pd.read_csv('/home/student/Downloads/datasets/titanic.csv')

print(df)

df.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = pd.read_csv('/home/student/Downloads/datasets/titanic.csv')

sns.displot(data.Survived)

plt.show()
display(data.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
import seaborn as sns
import pandas

data = pandas.read_csv('/home/student/Downloads/datasets/titanic.csv')

# plotting lineplot
sns.lineplot( x=data['Age'], y=data['Fare'])

# %%
import seaborn as snsdata 
# plo
import pandas

# read the csv data

sns.lineplot(x=data['Age'],y=data['Fare'], hue =data["Survived"])

# %%
sns.boxplot( data['Age'], data['Fare'])
# Out:
# /home/student/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.displot(data['Fare'])

# %%
import seaborn

seaborn.set(style = 'whitegrid')

# read csv and plot
data = pandas.read_csv('/home/student/Downloads/datasets/titanic.csv')
seaborn.swarmplot(x ="Age", y ="Fare",data = data)
# Out:
# /home/student/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/student/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 71.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/student/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 70.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/student/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import seaborn

seaborn.set(style = 'whitegrid')

# read csv and plot
data = pandas.read_csv('/home/student/Downloads/datasets/titanic.csv')
seaborn.swarmplot(x ="PassengerId", y ="Fare",data = data)

# %%
import seaborn

seaborn.sdata = pandas.read_csv('/home/student/Downloads/datasets/titanic.csv')

# read csv and plot
data = pandas.read_csv('/home/student/Downloads/datasets/titanic.csv')
seaborn.pointplot(x = "Age", y = "Fare", data = data)

# %%
import seaborn

seaborn.set(style = 'whitegrid')

# read csv and plot
data = pandas.read_csv('/home/student/Downloads/datasets/titanic.csv')
seaborn.countplot(data["Fare"])
# Out:
# /home/student/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
import pandas

# read csv and plotting
data = pandas.read_csv('/home/student/Downloads/datasets/titanic.csv')
sns.boxplot( data['Age'], data['Fare'])
# Out:
# /home/student/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn

seaborn.set(style = 'whitegrid')

# read csv and plot
data = pandas.read_csv('/home/student/Downloads/datasets/titanic.csv')
seaborn.violinplot(x ="Age", y ="Fare",data = data)

# %%
import seaborn as sns
import pandas

# read csv and plot
data = pandas.read_csv('/home/student/Downloads/datasets/titanic.csv')
sns.violinplot(data['Age'])
# Out:
# /home/student/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn
import pandas
data = pandas.read_csv('/home/student/Downloads/datasets/titanic.csv')

seaborn.scatterplot( data['Age'], data['Fare'], hue =data["PassengerId"])
# Out:
# /home/student/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn
import pandas

# load csv
data = pandas.read_csv('/home/student/Downloads/datasets/titanic.csv')

# plotting
seaborn.scatterplot(data['Age'],data['Fare'])
# Out:
# /home/student/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
import pandas

# read csv and plotting
data = pandas.read_csv('/home/student/Downloads/datasets/titanic.csv')
sns.boxplot( data['Age'] )
# Out:
# /home/student/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
