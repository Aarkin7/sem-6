# %%
import pandas as pd

data = pd.read_csv("titanic.csv")
data.head()
display(data.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#create seaborn boxplots by group
sns.boxplot(x='Age', y='Sex',hue='Survived', data=data)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#create seaborn boxplots by group
sns.boxplot(x='Sex', y='Age',hue='Survived', data=data)

# %%
plt.figure(figsize = (7,7),dpi=100)
ax = sns.FacetGrid(data=data,col='Pclass',row='Sex')
ax.map(sns.histplot,"Survived")
plt.show()

# %%
sns.jointplot(x = "Age", y = "Sex", kind = "scatter", data = data)

# %%
sns.jointplot(x = "Survived", y = "Age", kind = "scatter", data = data)

# %%
# From the above boxplot, we can derive the conclusion that, in male, the age of people who survived is around 20. 
# The median age of the survived males is around 27. The median age of people who didn't survive is around 29.
# The median age of the survived females is around 27. The median age of people who didn't survive is around 29.
# The median age of the survived males is around 27. The median age of people who didn't survive is around 29.
